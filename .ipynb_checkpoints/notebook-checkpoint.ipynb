# %%
from mpl_toolkits.mplot3d import Axes3D 
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import sys
sys.path.append('..')
from sklearn.neural_network import MLPClassifier
import matplotlib.pyplot as plt

from numpy import genfromtxt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import cross_val_score
import pickle
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import make_scorer
from imblearn.metrics import geometric_mean_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Normalizer

import numpy as np
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

data = np.genfromtxt(fname = '132234-imbalanced.txt', dtype='str')


X = data[1:,:-1].astype(np.float)
y = data[1:,-1].astype(np.float)
header = data[0]
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-345565c60502> in <module>
#      31 np.set_printoptions(suppress=True)
#      32
# ---> 33 data = np.genfromtxt(fname = '132234-imbalanced.txt', dtype='str')
#      34
#      35
#
# c:\users\luker\appdata\local\programs\python\python38-32\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    1770             fname = os_fspath(fname)
#    1771         if isinstance(fname, basestring):
# -> 1772             fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1773             fid_ctx = contextlib.closing(fid)
#    1774         else:
#
# ...

# %%
unique, counts = np.unique(y, return_counts=True)

print(unique[0],counts[0]/np.sum(counts))
print(unique[1],counts[1]/np.sum(counts))
# Out:
# 0.0 0.2598
# 1.0 0.7402

# %%
clf = DummyClassifier(strategy="most_frequent")

score = cross_val_score(clf, X, y, scoring=make_scorer(geometric_mean_score))
print(score)
score = cross_val_score(clf, X, y, scoring='accuracy')
print(score)

print(len(X))
# Out:
# [0. 0. 0. 0. 0.]
# [0.7403 0.7403 0.7403 0.74   0.74  ]
# 15000

# %%
mean_=[]
max_=[]
min_=[]
std = []
median = []

histogram=[]

for i in range(len(X[0])):
    mean_.append(np.mean(X[i,:]))
    std.append(np.std(X[i,:]))
    median.append(np.median(X[i,:]))
    min_.append(np.min(X[i,:]))
    max_.append(np.max(X[i,:]))
    print(header[i],np.mean(X[i,:]),np.std(X[i,:]),np.max((X[i,:])),np.min((X[i,:])))
# Out:
# dissim 1.3277801084033614 5.6950986566878425 51.051 -0.70359
# el0 1.6005588680672274 6.375662732065363 40.951 -0.6877
# el1 1.4072597605042017 5.341801216546328 31.579 -0.70094
# el2 2.1301503731092435 9.312411661438222 56.777 -0.70644
# el3 2.3308279873949576 10.419452836409405 64.752 -0.70547
# el4 1.7203863243697481 6.213981161176926 30.875 -0.69517
# el5 1.7404802084033615 8.708329920558091 54.963 -0.7067
# el6 1.8120735663865546 8.03720387184259 49.778 -0.65075
# el7 2.2909955473109243 8.97074199168357 49.621 -0.70559
# el8 2.03039083697479 9.75818993577007 60.842 -0.70346
# el9 1.329450749579832 5.0473751181804145 27.152 -0.70693
# el10 2.862483424369748 16.5255502189715 105.58 -0.68472
# el11 1.5206079428571428 7.056708251719562 60.925 -0.70401
# el12 4.353365811764707 26.044999245904126 166.29 -0.70707
# el13 2.046852354117647 9.10621969917895 53.959 -0.70711
# el14 1.3098959998319328 5.037129630226104 28.215 -0.70708
# ...

# %%
fig = plt.figure(figsize=(20, 8))
ax = fig.add_axes([1,1,1,1])
ax.bar(header[:-1],min_)
ax.set_title('Min wszystkich atrybutów')
plt.xticks(rotation=90)
plt.savefig("min.png", dpi=300, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(20, 8))
ax = fig.add_axes([1,1,1,1])
ax.bar(header[:-1],max_)
ax.set_title('Max wszystkich atrybutów')
plt.xticks(rotation=90)
plt.savefig("max.png", dpi=300, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(20, 8))
ax = fig.add_axes([1,1,1,1])
ax.bar(header[:-1],mean_)
ax.set_title('Średnie wszystkich atrybutów')
plt.xticks(rotation=90)
plt.savefig("mean.png", dpi=300, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(20, 8))
ax = fig.add_axes([1,1,1,1])
ax.bar(header[:-1],std)
ax.set_title('Odchylenia standardowe wszystkich atrybutów')
plt.xticks(rotation=90)
plt.savefig("std.png", dpi=300, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(20, 8))
ax = fig.add_axes([1,1,1,1])
ax.bar(header[:-1],median)
ax.set_title('Mediany wszystkich atrybutów')
plt.xticks(rotation=90)
plt.savefig("median.png", dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn.decomposition import PCA


X_scaled = StandardScaler().fit_transform(X)

pca = PCA(n_components=2)
pca_X = pca.fit_transform(X_scaled)
print(len(pca_X))

fig = plt.figure(2, figsize=(8, 6))
ax = fig.add_axes([1,1,1,1])

# Plot the training points
ax.set_title("Pierwsze 2 wektory PCA")
ax.scatter(pca_X[:, 0], pca_X[:, 1], c=y, cmap=plt.cm.Set1,
            edgecolor='k')

plt.xticks(())
plt.yticks(())

plt.savefig("2D.png", dpi=300, bbox_inches='tight')

fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)
X_reduced = PCA(n_components=3).fit_transform(X_scaled)
ax.scatter(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2], c=y,
           cmap=plt.cm.Set1, edgecolor='k', s=40)
ax.set_title("Pierwsze 3 wektory PCA")
ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.savefig("3D.png", dpi=300, bbox_inches='tight')
# Out:
# 15000

# %%
skf = StratifiedKFold(n_splits=10)
svc = svm.SVC()

# %%
# scoring_methods = {'acc' : 'accuracy',
#                   'b_acc' : 'balanced_accuracy',
#                   'g_mean' : make_scorer(geometric_mean_score)}

# param_grid = [
#   {'C': [0.1,1,10,100,1000,10000], 'gamma': [1,0.1,0.01,0.001,0.0001,0.00001], 'kernel': ['sigmoid',]},
#  ]

# clf_sigmoid = GridSearchCV(svc,param_grid, scoring=scoring_methods, cv = skf, n_jobs=-1, verbose=10, refit = False)
# clf_sigmoid.fit(X, y)

# pickle.dump(clf_sigmoid.cv_results_, open("sigmoid", "wb"))

file = open('sigmoid', 'rb')
sigmoid = pickle.load(file)

# %%
# scoring_methods = {'acc' : 'accuracy',
#                   'b_acc' : 'balanced_accuracy',
#                   'g_mean' : make_scorer(geometric_mean_score)}

# skf = StratifiedKFold(n_splits=10)
# scaler = StandardScaler()

# pipe = Pipeline([('transformer', StandardScaler()), ('SVC', svc)])

# param_grid = [{
#       'SVC__C': [0.1,1,10,100,1000,10000],
#       'SVC__gamma': [1,0.1,0.01,0.001,0.0001,0.00001],
#       'SVC__kernel': ['sigmoid']
# }]

# clf_sigmoid_transformed = GridSearchCV(pipe,
#                     param_grid=param_grid,
#                     scoring=scoring_methods,
#                     cv=skf,
#                     refit=False,
#                     n_jobs=-1,
#                     verbose=10)
# clf_sigmoid_transformed.fit(X, y)

# pickle.dump(clf_sigmoid_transformed.cv_results_, open("sigmoid_transformed", "wb"))

file = open('sigmoid_transformed', 'rb')
sigmoid_transformed = pickle.load(file)

# %%
# scoring_methods = {'acc' : 'accuracy',
#                   'b_acc' : 'balanced_accuracy',
#                   'g_mean' : make_scorer(geometric_mean_score)}

# skf = StratifiedKFold(n_splits=10)

# pipe = Pipeline([('transformer', Normalizer()), ('SVC', svc)])

# param_grid = [{
#       'SVC__C': [0.1,1,10,100,1000,10000],
#       'SVC__gamma': [1,0.1,0.01,0.001,0.0001,0.00001],
#       'SVC__kernel': ['sigmoid']
# }]

# clf_sigmoid_normalized = GridSearchCV(pipe,
#                     param_grid=param_grid,
#                     scoring=scoring_methods,
#                     cv=skf,
#                     refit=False,
#                     n_jobs=-1,
#                     verbose=10)
# clf_sigmoid_normalized.fit(X, y)

# pickle.dump(clf_sigmoid_normalized.cv_results_, open("sigmoid_normalized", "wb"))

file = open('sigmoid_normalized', 'rb')
sigmoid_normalized = pickle.load(file)

# %%
def heatmapper(scores,C_range,gamma_range):
    scores = scores.reshape(len(C_range),len(gamma_range))
    plt.figure(figsize=(8, 6))
    plt.subplots_adjust(left=.2, right=0.95, bottom=0.15, top=0.95)
    plt.imshow(scores, interpolation='nearest', cmap=plt.cm.hot)
    plt.xlabel('gamma')
    plt.ylabel('C')
    plt.colorbar()
    plt.xticks(np.arange(len(gamma_range)), gamma_range, rotation=45)
    plt.yticks(np.arange(len(C_range)), C_range)
    plt.title('Validation accuracy')
    plt.show()

heatmapper(sigmoid['mean_test_acc'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])
heatmapper(sigmoid['mean_test_b_acc'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])
heatmapper(sigmoid['mean_test_g_mean'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])

heatmapper(sigmoid_transformed['mean_test_acc'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])
heatmapper(sigmoid_transformed['mean_test_b_acc'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])
heatmapper(sigmoid_transformed['mean_test_g_mean'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])

heatmapper(sigmoid_normalized['mean_test_acc'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])
heatmapper(sigmoid_normalized['mean_test_b_acc'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])
heatmapper(sigmoid_normalized['mean_test_g_mean'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])

# %%
# scoring_methods = {'acc' : 'accuracy',
#                   'b_acc' : 'balanced_accuracy',
#                   'g_mean' : make_scorer(geometric_mean_score)}

# param_grid = [
#   {'C': [0.1,1,10,100,1000,10000], 'gamma': [1,0.1,0.01,0.001,0.0001,0.00001], 'kernel': ['rbf',]},
#  ]

# clf_rbf = GridSearchCV(svc,param_grid, scoring=scoring_methods, cv = skf, n_jobs=-1, verbose=10, refit = False)
# clf_rbf.fit(X, y)

# pickle.dump(clf_rbf.cv_results_, open("rbf", "wb"))

file = open('rbf', 'rb')
rbf = pickle.load(file)

# %%
# pipe = Pipeline([('transformer', Normalizer()), ('SVC', svc)])


# scoring_methods = {'acc' : 'accuracy',
#                   'b_acc' : 'balanced_accuracy',
#                   'g_mean' : make_scorer(geometric_mean_score)}

# param_grid = [{
#       'SVC__C': [0.1,1,10,100,1000,10000],
#       'SVC__gamma': [1,0.1,0.01,0.001,0.0001,0.00001],
#       'SVC__kernel': ['rbf']
# }]

# clf_rbf_normalized = GridSearchCV(pipe,param_grid, scoring=scoring_methods, cv = skf, verbose=10, n_jobs=6, refit = False)
# clf_rbf_normalized.fit(X, y)

# pickle.dump(clf_rbf_normalized.cv_results_, open("rbf_normalized", "wb"))

file = open('rbf_normalized', 'rb')
rbf_normalized = pickle.load(file)

# %%
heatmapper(rbf['mean_test_acc'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])
heatmapper(rbf['mean_test_b_acc'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])
heatmapper(rbf['mean_test_g_mean'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])

heatmapper(rbf_normalized['mean_test_acc'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])
heatmapper(rbf_normalized['mean_test_b_acc'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])
heatmapper(rbf_normalized['mean_test_g_mean'], [0.1,1,10,100,1000,10000], [1,0.1,0.01,0.001,0.0001,0.00001])
